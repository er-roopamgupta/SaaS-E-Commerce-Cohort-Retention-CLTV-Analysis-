# %%
import pandas as pd
sales_data = pd.read_csv(r"C:\Users\Sakshi Pawar\Downloads\Ecommerce_Transactions_Clean.csv")
top_categories = sales_data.groupby('Product_Category')['Total_Amount'].sum().reset_index()
top_categories = top_categories.sort_values(by='Total_Amount', ascending=False).head(5)
top_categories.style.format({'Total_Amount': '₹{:,.2f}'})
# Out:
# <style type="text/css">
# </style>
# <table id="T_de10c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_de10c_level0_col0" class="col_heading level0 col0" >Product_Category</th>
#       <th id="T_de10c_level0_col1" class="col_heading level0 col1" >Total_Amount</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_de10c_level0_row0" class="row_heading level0 row0" >4</th>
#       <td id="T_de10c_row0_col0" class="data row0 col0" >Fashion</td>
#       <td id="T_de10c_row0_col1" class="data row0 col1" >₹1,151,641.00</td>
#     </tr>
#     <tr>
#       <th id="T_de10c_level0_row1" class="row_heading level0 row1" >7</th>
#       <td id="T_de10c_row1_col0" class="data row1 col0" >Home & Kitchen</td>
#       <td id="T_de10c_row1_col1" class="data row1 col1" >₹1,095,194.00</td>
#     </tr>
#     <tr>
#       <th id="T_de10c_level0_row2" class="row_heading level0 row2" >1</th>
# ...
