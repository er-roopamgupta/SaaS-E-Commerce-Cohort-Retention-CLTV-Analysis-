# %%
# Create a cross-tabulation of acquisition channels and payment status
payment_analysis = pd.crosstab(
    sales_data['Acquisition_Channel'], 
    sales_data['Payment_Status'], 
    normalize='index'
) * 100

# Display the percentage breakdown for each channel
payment_analysis.round(2).astype(str) + '%'
# Out:
# Payment_Status      Failed Refunded Success
# Acquisition_Channel
# Amazon               3.94%    4.72%  91.34%
# Email                1.89%    5.05%  93.06%
# Facebook Ads         3.06%    6.96%  89.97%
# Google Ads           3.08%    3.34%  93.57%
# Instagram            4.38%    4.38%  91.23%
# Organic Search        3.0%    5.25%  91.75%
# YouTube              2.69%    5.09%  92.22%
