# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# 1. Load the dataset
df = pd.read_csv('Ecommerce_Transactions_Clean.csv')

# 2. Filter for successful transactions to measure true customer retention
df = df[df['Payment_Status'] == 'Success'].copy()

# 3. Convert Purchase_Date to datetime format
df['Purchase_Date'] = pd.to_datetime(df['Purchase_Date'])

df.head()
# Out:
#   Transaction_ID Customer_ID Purchase_Date Product_Category Product_Name  \
# 0        T000001       C0001    2025-11-13      Electronics      Monitor
# 1        T000002       C0002    2025-08-16            Books        Novel
# 2        T000003       C0002    2025-09-30      Accessories       Wallet
# 3        T000004       C0003    2025-07-04           Beauty      Perfume
# 4        T000005       C0004    2025-09-13      Electronics   Headphones
#
#    Quantity  Unit_Price  Total_Amount Payment_Status Acquisition_Channel  \
# 0         3        2398          7194        Success      Organic Search
# 1         1         999           999        Success          Google Ads
# 2         3        2999          8997        Success          Google Ads
# 3         3         299           897        Success           Instagram
# 4         1        7498          7498        Success        Facebook Ads
#
#   Customer_Segment     City        State Gender Age_Group
# ...

# %%
# Extract the month of the transaction (YYYY-MM)
df['Transaction_Month'] = df['Purchase_Date'].dt.to_period('M')

# Find the earliest transaction month for each customer
df['Cohort_Month'] = df.groupby('Customer_ID')['Transaction_Month'].transform('min')

df[['Customer_ID', 'Purchase_Date', 'Transaction_Month', 'Cohort_Month']].head()
# Out:
#   Customer_ID Purchase_Date Transaction_Month Cohort_Month
# 0       C0001    2025-11-13           2025-11      2025-11
# 1       C0002    2025-08-16           2025-08      2025-08
# 2       C0002    2025-09-30           2025-09      2025-08
# 3       C0003    2025-07-04           2025-07      2025-07
# 4       C0004    2025-09-13           2025-09      2025-09
