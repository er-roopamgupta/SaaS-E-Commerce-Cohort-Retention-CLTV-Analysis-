# %%
######## Aggregate total revenue by cohort and cohort index
revenue_matrix = df.groupby(['Cohort_Month', 'Cohort_Index'])['Total_Amount'].sum().unstack(fill_value=0)

print("--- Total Revenue Matrix by Cohort ---")
print(revenue_matrix)
# Out:
# --- Total Revenue Matrix by Cohort ---
# Cohort_Index       0       1       2       3       4      5     6     7
# Cohort_Month
# 2025-01       306660  153137  173286   62509   16930   2999   799     0
# 2025-02       384812  223599   91787   74624   18995      0     0     0
# 2025-03       370809  250746  174931  110492   77296  14481     0     0
# 2025-04       321128  211359  150896   56448    3995   5997     0     0
# 2025-05       238480  143710   81104   35047   32483      0     0     0
# 2025-06       342850  201720  172950  145436  110133  58239  1719  2874
# 2025-07       305602  163326   85625  121673   61653  20620     0     0
# 2025-08       413023  215305  135591   58351   23736  15796     0     0
# 2025-09       446726  297728  221571   70015   25660  34139     0     0
# 2025-10       348538  196876   97988   48856     998   9595     0     0
# 2025-11       320959  161324   71158   50417   46543   6590     0     0
# ...
