# %%
import pandas as pd

# %%
### Best Selling Products with Revenue

best_products = df.groupby('Product_Name').agg(
    Total_Quantity=('Quantity', 'sum'),
    Total_Revenue=('Total_Amount', 'sum')
).reset_index()

best_products = best_products.sort_values(
    by='Total_Quantity',
    ascending=False
).head(10)

best_products
# Out:
#    Product_Name  Total_Quantity  Total_Revenue
# 17        Novel             286         519798
# 16     Notebook             276         506325
# 22     Sneakers             267         478746
# 2         Boots             260         501356
# 1        Blocks             247         512367
# 20       Puzzle             241         421327
# 19      Perfume             192         395667
# 3        Bottle             190         347669
# 7     Face Wash             189         339529
# 13     Lipstick             183         354567
